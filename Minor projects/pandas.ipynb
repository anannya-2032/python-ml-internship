# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\bestsellers.csv")
df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import pandas as pd
df1=pd.read_excel(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\bestsellers.xlsx")
df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import pandas as pd
df_json=pd.read_json(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\data.json")

print(df_json.to_string())
# Out:
#                Name         Country             House    Reign  ID
# 0  Edward the Elder  United Kingdom   House of Wessex  899-925   1
# 1         Athelstan           China  House in Beijing  925-940   2
# 2            Edmund           India    House in Delhi  940-946   3
# 3             Edred  United Kingdom   House of Wessex  946-955   4
# 4              Edwy       Australia    House in Wales  955-959   5

# %%
df1.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df1.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
df1.head(60)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df1.head(50)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df1.tail(50)
# Out:
#                                                   Name  \
# 500  Thug Kitchen: The Official Cookbook: Eat Like ...
# 501  Thug Kitchen: The Official Cookbook: Eat Like ...
# 502  Thug Kitchen: The Official Cookbook: Eat Like ...
# 503  Thug Kitchen: The Official Cookbook: Eat Like ...
# 504                               Tina Fey: Bossypants
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
# 509                              To Kill a Mockingbird
# 510  Tools of Titans: The Tactics, Routines, and Ha...
# 511  Towers of Midnight (Wheel of Time, Book Thirteen)
# 512                             True Compass: A Memoir
# 513               Twilight (The Twilight Saga, Book 1)
# 514  Ultimate Sticker Book: Frozen: More Than 60 Re...
# 515  Unbroken: A World War II Story of Survival, Re...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df1.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df1.shape
# Out:
# (550, 7)

# %%
df1.rename(columns={'Author':'Writer','Price':'Amount'},inplace=True)
df1.columns
# Out:
# Index(['Name', 'Writer', 'User Rating', 'Reviews', 'Amount', 'Year', 'Genre'], dtype='object')

# %%
df4=pd.read_csv(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\ramen-ratings.csv")
df4
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %%
#demo to  handle nuls
df4.isnull()
# Out:
#       Review #  Brand  Variety  Style  Country  Stars  Top Ten
# 0        False  False    False  False    False  False     True
# 1        False  False    False  False    False  False     True
# 2        False  False    False  False    False   True     True
# 3        False  False    False  False    False  False     True
# 4        False  False    False  False    False  False     True
# ...        ...    ...      ...    ...      ...    ...      ...
# 2575     False  False    False  False    False  False     True
# 2576     False  False    False  False    False  False     True
# 2577     False  False    False  False    False  False     True
# 2578     False  False    False  False    False  False     True
# 2579     False  False    False  False    False  False     True
#
# [2580 rows x 7 columns]

# %%
df4.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars         21
# Top Ten     2539
# dtype: int64

# %%
#imputation -fillna() -> fill not applicable (null) values

df4["Style"].fillna("No Pack",inplace=True)

# %%
df4.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          0
# Country        0
# Stars         21
# Top Ten     2539
# dtype: int64

# %%
df4["Top Ten"].fillna("No Rank",inplace=True)

# %%
df4.isnull().sum()
# Out:
# Review #     0
# Brand        0
# Variety      0
# Style        0
# Country      0
# Stars       21
# Top Ten      0
# dtype: int64

# %%
df4
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %%
mean_val=df4["Stars"].mean()
mean_val
# Out:
# 3.6505861664712773

# %%
df4["Stars"].fillna(value=mean_val,inplace=True)
df4.isnull().sum()
# Out:
# Review #    0
# Brand       0
# Variety     0
# Style       0
# Country     0
# Stars       0
# Top Ten     0
# dtype: int64

# %%
df4
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %%
value_changetype={'Stars':object}
df4=df4.astype(value_changetype)
print(df4.dtypes)
# Out:
# Review #     int64
# Brand       object
# Variety     object
# Style       object
# Country     object
# Stars       object
# Top Ten     object
# dtype: object

# %%
df4["Brand"].value_counts().head(50)
# Out:
# Brand
# Nissin              381
# Nongshim             98
# Maruchan             76
# Mama                 71
# Paldo                66
# Myojo                63
# Indomie              53
# Samyang Foods        52
# Ottogi               46
# Lucky Me!            34
# Vina Acecook         34
# Vifon                33
# Maggi                30
# Mamee                29
# Master Kong          28
# MAMA                 27
# A-Sha Dry Noodle     26
# KOKA                 25
# Wai Wai              25
# Sapporo Ichiban      25
# MyKuali              24
# Ve Wong              24
# JML                  23
# Samyang              19
# Koka                 18
# Batchelors           16
# Doll                 16
# Mr. Noodles          15
# Kamfen               15
# Acecook              15
# Wei Lih              15
# Takamori Kosan       14
# Asian Thai Foods     14
# Little Cook          14
# Sau Tao              14
# Vit's                13
# Deshome              13
# Unif                 13
# ...

# %%
df4["Brand"].value_counts()
# Out:
# Brand
# Nissin           381
# Nongshim          98
# Maruchan          76
# Mama              71
# Paldo             66
#                 ...
# Golden Wonder      1
# Peyang             1
# Sanrio             1
# China Best         1
# Westbrae           1
# Name: count, Length: 355, dtype: int64

# %%
df4["Style"].value_counts()
# Out:
# Style
# Pack       1531
# Bowl        481
# Cup         450
# Tray        108
# Box           6
# No Pack       2
# Can           1
# Bar           1
# Name: count, dtype: int64

# %%
df4["Style"].value_counts().head(10)
# Out:
# Style
# Pack       1531
# Bowl        481
# Cup         450
# Tray        108
# Box           6
# No Pack       2
# Can           1
# Bar           1
# Name: count, dtype: int64

# %%
df4["Brand"].value_counts().tail()
# Out:
# Brand
# Golden Wonder    1
# Peyang           1
# Sanrio           1
# China Best       1
# Westbrae         1
# Name: count, dtype: int64

# %%
# 1. .loc- locates rows by a name in the index column or first column
# 2. .iloc- locates rows by numerical index

df6=pd.read_csv(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\ramen-ratings.csv", index_col="Stars")
row_out1=df6.loc[4]
row_out1
# Out:
#        Review #             Brand                                   Variety  \
# Stars
# 4.0        2562          Binh Tay                                Mi Hai Cua
# 4.0        2561             Paldo                           Premium Gomtang
# 4.0        2551              KOKA  Signature Tom Yum Flavor Instant Noodles
# 4.0        2547  Sichuan Guangyou               Chongqing Spicy Hot Noodles
# 4.0        2534          Fujiwara             Hokkaido Hakodate Shoyu Ramen
# ...         ...               ...                                       ...
# 4.0          31             Myojo                        Ippeichan Yakisoba
# 4.0          27            Nissin                  Demae Ramen Curry Flavor
# 4.0          26            Nissin     Soba Noodles With Mayo Mustard Squirt
# 4.0          21          Nongshim                 Champong Oriental Noodles
# 4.0          19          Nongshim                               Shin Ramyun
#
#       Style      Country  Top Ten
# Stars
# ...

# %%
df6=pd.read_csv(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\ramen-ratings.csv", index_col="Country")
row_out1=df6.loc["South Korea"]
row_out1
# Out:
#              Review #          Brand                             Variety  \
# Country
# South Korea      2575  Samyang Foods              Kimchi song Song Ramen
# South Korea      2568       Nongshim  Mr. Bibim Stir-Fried Kimchi Flavor
# South Korea      2561          Paldo                     Premium Gomtang
# South Korea      2555  Samyang Foods           Song Song Kimchi Big Bowl
# South Korea      2550  Samyang Foods                    Paegaejang Ramen
# ...               ...            ...                                 ...
# South Korea        16        Samyang                   Kalgug-Su (Spicy)
# South Korea        15        Samyang                  Pojangmacha U-dong
# South Korea        14        Samyang                                 Hot
# South Korea        11    Six Fortune  Chicken Flavor Instant Soup Noodle
# South Korea         9          Sutah                          Cup Noodle
#
#             Style  Stars Top Ten
# Country
# South Korea  Pack   4.75     NaN
# ...

# %%
row2=df6.iloc[2]
row2
# Out:
# Review #                             2578
# Brand                              Nissin
# Variety     Cup Noodles Chicken Vegetable
# Style                                 Cup
# Stars                                 NaN
# Top Ten                               NaN
# Name: USA, dtype: object

# %%
rows=df6.iloc[0:11]
rows
# Out:
#              Review #           Brand  \
# Country
# Japan            2580       New Touch
# Taiwan           2579        Just Way
# USA              2578          Nissin
# Taiwan           2577         Wei Lih
# India            2576  Ching's Secret
# South Korea      2575   Samyang Foods
# Japan            2574         Acecook
# Japan            2573     Ikeda Shoku
# Japan            2572      Ripe'n'Dry
# Singapore        2571            KOKA
# Thailand         2570     Tao Kae Noi
#
#                                                        Variety Style  Stars  \
# Country
# Japan                                T's Restaurant Tantanmen    Cup   3.75
# Taiwan       Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack   1.00
# USA                              Cup Noodles Chicken Vegetable   Cup    NaN
# Taiwan                           GGE Ramen Snack Tomato Flavor  Pack   2.75
# India                                          Singapore Curry  Pack   3.75
# ...

# %%
rows2=df6.iloc[0:11:2]
rows2
# Out:
#           Review #           Brand                              Variety Style  \
# Country
# Japan         2580       New Touch            T's Restaurant Tantanmen    Cup
# USA           2578          Nissin        Cup Noodles Chicken Vegetable   Cup
# India         2576  Ching's Secret                      Singapore Curry  Pack
# Japan         2574         Acecook  Spice Deli Tantan Men With Cilantro   Cup
# Japan         2572      Ripe'n'Dry             Hokkaido Soy Sauce Ramen  Pack
# Thailand      2570     Tao Kae Noi          Creamy tom Yum Kung Flavour  Pack
#
#           Stars Top Ten
# Country
# Japan      3.75     NaN
# USA         NaN     NaN
# India      3.75     NaN
# Japan       NaN     NaN
# Japan      0.25     NaN
# Thailand    NaN     NaN
