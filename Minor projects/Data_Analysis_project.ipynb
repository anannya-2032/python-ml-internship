# %%
import pandas as pd
import numpy as np
import seaborn as sns

pstore=pd.read_csv(r"C:\Users\Dell\Desktop\PYTHON ML INTERNSHIP\database\googleplaystore.csv")
pstore.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
pstore.shape
# Out:
# (10841, 13)

# %%
print(pstore.info())
print(pstore.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            10841 non-null  object
#  1   Category       10841 non-null  object
#  2   Rating         9367 non-null   float64
#  3   Reviews        10841 non-null  int64
#  4   Size           10841 non-null  object
#  5   Installs       10841 non-null  object
#  6   Type           10840 non-null  object
#  7   Price          10841 non-null  object
#  8   ContentRating  10841 non-null  object
#  9   Genres         10840 non-null  object
#  10  LastUpdated    10841 non-null  object
#  11  CurrentVer     10833 non-null  object
#  12  AndroidVer     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB
# None
#            App Category       Rating       Reviews                Size  \
# ...

# %%
print(pstore.isnull().sum())
# Out:
# App                 0
# Category            0
# Rating           1474
# Reviews             0
# Size                0
# Installs            0
# Type                1
# Price               0
# ContentRating       0
# Genres              1
# LastUpdated         0
# CurrentVer          8
# AndroidVer          2
# dtype: int64

# %%
pstore=pstore.dropna()
print(pstore.isnull().sum())
# Out:
# App              0
# Category         0
# Rating           0
# Reviews          0
# Size             0
# Installs         0
# Type             0
# Price            0
# ContentRating    0
# Genres           0
# LastUpdated      0
# CurrentVer       0
# AndroidVer       0
# dtype: int64

# %%
pstore["Reviews"]=pd.to_numeric(pstore["Reviews"],errors="coerce")
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pstore["Installs"]=pstore["Installs"].str.replace("+","").str.replace(",","").astype(int)

# %%
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            9360 non-null   object
#  1   Category       9360 non-null   object
#  2   Rating         9360 non-null   float64
#  3   Reviews        9360 non-null   int64
#  4   Size           9360 non-null   object
#  5   Installs       9360 non-null   int32
#  6   Type           9360 non-null   object
#  7   Price          9360 non-null   object
#  8   ContentRating  9360 non-null   object
#  9   Genres         9360 non-null   object
#  10  LastUpdated    9360 non-null   object
#  11  CurrentVer     9360 non-null   object
#  12  AndroidVer     9360 non-null   object
# dtypes: float64(1), int32(1), int64(1), object(10)
# memory usage: 987.2+ KB

# %%
pstore["Price"]=pstore["Price"].str.replace('$', '').astype(float)
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pstore['LastUpdated'] = pd.to_datetime(pstore['LastUpdated'])
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pstore = pstore.drop_duplicates()
pstore.shape
# Out:
# (8886, 13)

# %%
pstore["Size"]=pstore["Size"].replace("Varies with device",np.nan)
pstore
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_29052\3841698146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pstore["Size"]=pstore["Size"].replace("Varies with device",np.nan)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# ...

# %%
def convert_size(size):
    if "M" in size:
        return float(size.replace("M"," "))
    elif "k" in size:
        return float(size.replace("k"," "))/1000
    else:
        return np.nan

pstore["Size"]=pstore["Size"].apply(lambda x:convert_size(x) if isinstance (x,str) else x)
pstore
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_29052\2916614233.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pstore["Size"]=pstore["Size"].apply(lambda x:convert_size(x) if isinstance (x,str) else x)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...

# %%
category_data = pstore.groupby('Category')[['Rating', 'Reviews',"Installs"]].mean().round(2)
print(category_data)
# Out:
#                      Rating     Reviews     Installs
# Category
# ART_AND_DESIGN         4.38    28103.56   2036526.23
# AUTO_AND_VEHICLES      4.19    15940.14    727805.48
# BEAUTY                 4.28     9407.93    640861.90
# BOOKS_AND_REFERENCE    4.35   123575.24  10826506.53
# BUSINESS               4.10    45769.28   3198215.26
# COMICS                 4.16    58309.40    966139.66
# COMMUNICATION          4.15  1958544.27  78671796.51
# DATING                 3.97    34875.25   1298883.08
# EDUCATION              4.38   179571.50   4138387.60
# ENTERTAINMENT          4.14   428565.01  22123063.06
# EVENTS                 4.44     3568.67    354431.33
# FAMILY                 4.19   231082.44   5848037.62
# FINANCE                4.13    53626.40   2430007.57
# FOOD_AND_DRINK         4.16    72370.33   2431865.57
# GAME                   4.28  1318001.75  29370449.46
# HEALTH_AND_FITNESS     4.26   117729.26   5194680.23
# ...

# %%
correlation=pstore[["Reviews","Rating","Size","Installs","Price"]].corr()
correlation
# Out:
#            Reviews    Rating      Size  Installs     Price
# Reviews   1.000000  0.068724  0.240069  0.633422 -0.009562
# Rating    0.068724  1.000000  0.081871  0.050869 -0.022371
# Size      0.240069  0.081871  1.000000  0.166979 -0.026853
# Installs  0.633422  0.050869  0.166979  1.000000 -0.011334
# Price    -0.009562 -0.022371 -0.026853 -0.011334  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.heatmap(correlation, annot=True , cmap="crest")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.distplot(pstore.Rating, color="c")
plt.title("Distribution Plot for Google App Ratings", fontsize=12, color = 'g')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_29052\1484137652.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pstore.Rating, color="c")
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=[5,10])
pstore["ContentRating"].value_counts().plot.pie()
plt.show()

# %%
sns.set_style("dark")

# %%
plt.figure(figsize=[5,5])
pstore["ContentRating"].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=[9,7])
pstore["ContentRating"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='ContentRating'>

# %%
pivot_table=pstore.pivot_table(values=["Rating","Reviews"],index="Category",aggfunc={"Rating":"mean","Reviews":"sum"})
pivot_table=pivot_table.reset_index()
pivot_table
# Out:
#                Category    Rating     Reviews
# 0        ART_AND_DESIGN  4.377049     1714317
# 1     AUTO_AND_VEHICLES  4.190411     1163630
# 2                BEAUTY  4.278571      395133
# 3   BOOKS_AND_REFERENCE  4.347458    21872818
# 4              BUSINESS  4.102593    12357705
# 5                COMICS  4.155172     3381945
# 6         COMMUNICATION  4.151466   601273091
# 7                DATING  3.971698     5545164
# 8             EDUCATION  4.375969    23164724
# 9         ENTERTAINMENT  4.136036    47570716
# 10               EVENTS  4.435556      160590
# 11               FAMILY  4.191264   396768541
# 12              FINANCE  4.127445    16999569
# 13       FOOD_AND_DRINK  4.164151     7671255
# 14                 GAME  4.281285  1415533878
# 15   HEALTH_AND_FITNESS  4.261450    30845065
# 16       HOUSE_AND_HOME  4.164706     2794391
# 17   LIBRARIES_AND_DEMO  4.179688     1013390
# 18            LIFESTYLE  4.096066    12819560
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Category",y="Installs",data=pstore,estimator=np.mean, errorbar=("ci",100))
plt.xticks(rotation=90)
plt.title("Average Installs by Category", fontsize=18)
plt.show()

# %%
avg_installs_by_type=pstore.groupby(["Category","Type"])["Installs"].mean().reset_index()

plt.figure(figsize=(14,8))
sns.barplot(x="Category",y="Installs",hue="Type",data=avg_installs_by_type, palette="pastel")
plt.xticks(rotation=90)
plt.title("Average Number of Installs By Category (Free vs Paid)",fontsize=20)
plt.xlabel("Average Number of Installs",fontsize=15)
plt.ylabel("Category",fontsize=15)
plt.legend(title="Type",fontsize=15)
plt.show()

# %%
pstore["Year"]=pstore["LastUpdated"].dt.year
avg_rating_per_year=pstore.groupby("Year")["Rating"].mean().reset_index()
plt.figure(figsize=(10,6))
sns.lineplot(x="Year",y="Rating",data=avg_rating_per_year,marker="o")
sns.regplot(x="Year",y"Rating",data=avg_rating_per_year, scatter=False, color="r", line_kws=
# Out:
#   Cell In[65], line 5
#     sns.regplot(x="Year",y"Rating",data=avg_rating_per_year, scatter=False, color="r", line_kws=
#                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.figure(figsize=(12,8))
sns.pairplot(pstore[["Rating","Reviews","Size","Installs","Price"]])
plt.title("Pair Plot of Numerical Features")
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Category",y="Rating",data=pstore)
plt.xticks(rotation=90)
plt.title("Box Plot of Rating by Category",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Category",y="Reviews",data=pstore)
plt.xticks(rotation=90)
plt.title("Box Plot of Reviews by Category",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="Category",y="Rating",data=pstore,inner="quartile",showmedians=True)
plt.xticks(rotation=90)
plt.title("Violin Plot of App Ratings by Category",fontsize=15)
plt.xlabel("Category",fontsize=12)
plt.ylabel("Rating",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Reviews",y="Rating",data=pstore)
plt.title("Scatter Plot of Reviews vs Ratings",fontsize=15)
plt.xlabel("Number of Reviews", fontsize=12)
plt.ylabel("Rating",fontsize=12)
plt.xscale("log")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Type",data=pstore)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
plt.figure(figsize=(14,8))
sns.countplot(y="Category",data=pstore,order=pstore["Category"].value_counts().index)
plt.title("Conut Plot of App Categories",fontsize=15)
plt.xlabel("Count",fontsize=12)
plt.ylabel("Category",fontsize=12)
plt.show()
